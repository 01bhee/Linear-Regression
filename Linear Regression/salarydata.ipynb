# %% [markdown]
# IMPORTING LIBRARIES

# %%
import numpy as nP
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
#     IMPORTING DATASET AND DECLARING INDEPENDENT AND TARGET VARIABLES

# %%
dataset = pd.read_csv('Salary_Data.csv')
X =  dataset.iloc[:, :-1].values #Independent variable which is Years of Experience
Y = dataset.iloc[:, -1].values #Target variablle which is the salary
#We are trying to predict the salary of users based on their years of experience

# %% [markdown]
# SPLITTING DATASET INTO TRAINING AND TESTING SET

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 0)

# %% [markdown]
# TRAINING THE LINEAR REGRESSION MODEL ON THE THRAINING SETS

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# PREDICTING THE TEST SET RESULTS

# %%
Y_pred = model.predict (X_test)

# %% [markdown]
# VISUALIZING THE TRAINING SET

# %%
plt.scatter(X_train, Y_train, color = 'green')
plt.plot(X_train, model.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# VISUALISING THE TEST SET RESULTS

# %%
plt.scatter(X_test, Y_test, color = 'red')
plt.plot(X_test, model.predict(X_test), color = 'blue')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
